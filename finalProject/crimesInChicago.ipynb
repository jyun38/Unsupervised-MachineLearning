# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 
#hello
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df1 = pd.read_csv("../../crimesInChicagoData/Chicago_Crimes_2001_to_2004.csv", error_bad_lines = False)
# Out:
# b'Skipping line 1513591: expected 23 fields, saw 24\n'
# //anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2 = pd.read_csv("../../crimesInChicagoData/Chicago_Crimes_2005_to_2007.csv", error_bad_lines = False)
# Out:
# b'Skipping line 533719: expected 23 fields, saw 24\n'

# %%
df3 = pd.read_csv("../../crimesInChicagoData/Chicago_Crimes_2008_to_2011.csv", error_bad_lines = False)
# Out:
# b'Skipping line 1149094: expected 23 fields, saw 41\n'

# %%
df4 = pd.read_csv("../../crimesInChicagoData/Chicago_Crimes_2012_to_2017.csv", error_bad_lines = False)

# %%
df4
# Out:
#          Unnamed: 0        ID Case Number                    Date  \
# 0                 3  10508693    HZ250496  05/03/2016 11:40:00 PM
# 1                89  10508695    HZ250409  05/03/2016 09:40:00 PM
# 2               197  10508697    HZ250503  05/03/2016 11:31:00 PM
# 3               673  10508698    HZ250424  05/03/2016 10:10:00 PM
# 4               911  10508699    HZ250455  05/03/2016 10:00:00 PM
# 5              1108  10508702    HZ250447  05/03/2016 10:35:00 PM
# 6              1130  10508703    HZ250489  05/03/2016 10:30:00 PM
# 7              1801  10508704    HZ250514  05/03/2016 09:30:00 PM
# 8              1868  10508709    HZ250523  05/03/2016 04:00:00 PM
# 9              1891  10508982    HZ250667  05/03/2016 10:30:00 PM
# 10             1935  10508710    HZ250469  05/03/2016 09:44:00 PM
# 11             2150  10508715    HZ250541  05/03/2016 11:11:00 PM
# 12             2193  10508717    HZ250415  05/03/2016 05:30:00 PM
# ...

# %%
df3.Date.unique()
# Out:
# array(['10/07/2008 12:39:00 PM', '10/09/2008 03:30:00 AM',
#        '10/09/2008 08:35:00 AM', ..., '09/17/2008 04:39:00 PM',
#        '10/04/2008 03:43:00 AM', '10/05/2008 08:32:00 AM'], dtype=object)

# %%
type(df4['Date'])
# Out:
# pandas.core.series.Series

# %%
df4_try = df4

# %%
df4_try['Date'] = pd.to_datetime(df4['Date'])

# %%
df4_try['Date'].dt

# %%
df4.head()
# Out:
#    Unnamed: 0        ID Case Number                Date                Block  \
# 0           3  10508693    HZ250496 2016-05-03 23:40:00   013XX S SAWYER AVE
# 1          89  10508695    HZ250409 2016-05-03 21:40:00   061XX S DREXEL AVE
# 2         197  10508697    HZ250503 2016-05-03 23:31:00  053XX W CHICAGO AVE
# 3         673  10508698    HZ250424 2016-05-03 22:10:00    049XX W FULTON ST
# 4         911  10508699    HZ250455 2016-05-03 22:00:00    003XX N LOTUS AVE
#
#    IUCR            Primary Type              Description Location Description  \
# 0  0486                 BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT
# 1  0486                 BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE
# 2  0470  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT               STREET
# 3  0460                 BATTERY                   SIMPLE             SIDEWALK
# 4  0820                   THEFT           $500 AND UNDER            RESIDENCE
#
# ...

# %%
df4['Date'].sort_values(ascending=True)
# Out:
# 469324    2012-01-01 00:00:00
# 382599    2012-01-01 00:00:00
# 1391069   2012-01-01 00:00:00
# 78098     2012-01-01 00:00:00
# 1156939   2012-01-01 00:00:00
# 490105    2012-01-01 00:00:00
# 235002    2012-01-01 00:00:00
# 1360382   2012-01-01 00:00:00
# 159632    2012-01-01 00:00:00
# 247998    2012-01-01 00:00:00
# 412482    2012-01-01 00:00:00
# 1307680   2012-01-01 00:00:00
# 1233062   2012-01-01 00:00:00
# 347985    2012-01-01 00:00:00
# 99438     2012-01-01 00:00:00
# 158639    2012-01-01 00:00:00
# 77947     2012-01-01 00:00:00
# 28378     2012-01-01 00:00:00
# 215362    2012-01-01 00:00:00
# 86111     2012-01-01 00:00:00
# 64164     2012-01-01 00:00:00
# 213351    2012-01-01 00:00:00
# 367102    2012-01-01 00:00:00
# 81338     2012-01-01 00:00:00
# 236019    2012-01-01 00:00:00
# 1369353   2012-01-01 00:00:00
# 291825    2012-01-01 00:00:00
# 77841     2012-01-01 00:00:00
# 754303    2012-01-01 00:00:00
# 77290     2012-01-01 00:00:00
#                   ...
# ...

# %%
df4['Date'].dt.year.value_counts()
# Out:
# 2012    335670
# 2013    306703
# 2014    274527
# 2016    265462
# 2015    262995
# 2017     11357
# Name: Date, dtype: int64

# %%
df1['Date'].sort_values(ascending=True)

# %%
df1_byYear = df1['Date'].dt.year.value_counts()

# %%
df1_byYear

# %%
df1_byYear = pd.DataFrame(df1['Date'].dt.year.value_counts())

# %%
df2_byYear = pd.DataFrame(df2['Date'].dt.year.value_counts())

# %%
df3_byYear = pd.DataFrame(df3['Date'].dt.year.value_counts())

# %%
df4_byYear = pd.DataFrame(df4['Date'].dt.year.value_counts())

# %%
summary_byYear = pd.concat([df1_byYear, df2_byYear, df3_byYear, df4_byYear], axis=0)

# %%
summary_byYear = summary_byYear.rename(columns={'Date': 'Count'})

# %%
summary_byYear

# %%
summary_byYear.index.rename('foo', inplace=True)

# %%
summary_byYear.index.name='Year'

# %%
summary_byYear['Year'] = summary_byYear.index

# %%
summary_byYear = summary_byYear.reset_index(drop=True)

# %%
summary_byYear

# %%
columnsTitles=["Year","Count"]
summary_byYear=summary_byYear.reindex(columns=columnsTitles)

# %%
summary_byYear

# %%
''' Takes in dataframe to change data type to datetime and returns the count per year
'''
def countPerYear(df):
    df['Date'] = pd.to_datetime(df['Date'])
    return df['Date'].dt.year.value_counts()

# %%
countPerYear(df1)
# Out:
# 2001    568518
# 2002    490879
# 2003    475913
# 2004    388205
# Name: Date, dtype: int64

# %%
df2['Date'].sort_values(ascending=True)

# %%
countPerYear(df2)
# Out:
# 2006    794684
# 2007    621848
# 2005    455811
# Name: Date, dtype: int64

# %%
countPerYear(df4)
# Out:
# 2012    335670
# 2013    306703
# 2014    274527
# 2016    265462
# 2015    262995
# 2017     11357
# Name: Date, dtype: int64

# %%
countPerYear(df3)
# Out:
# 2008    852053
# 2009    783900
# 2010    700691
# 2011    352066
# Name: Date, dtype: int64

# %%
allYears = pd.concat([countPerYear(df1), countPerYear(df2), countPerYear(df3), countPerYear(df4)], axis=0)

# %%
allYears
# Out:
# 2001    568518
# 2002    490879
# 2003    475913
# 2004    388205
# 2006    794684
# 2007    621848
# 2005    455811
# 2008    852053
# 2009    783900
# 2010    700691
# 2011    352066
# 2012    335670
# 2013    306703
# 2014    274527
# 2016    265462
# 2015    262995
# 2017     11357
# Name: Date, dtype: int64

# %%
dfTotal = pd.concat([df1, df2, df3, df4], axis = 0)

# %%
dfTotal
# Out:
#          Unnamed: 0        ID Case Number                Date  \
# 0               879   4786321    HM399414 2004-01-01 00:01:00
# 1              2544   4676906    HM278933 2003-03-01 00:00:00
# 2              2919   4789749    HM402220 2004-06-20 11:00:00
# 3              2927   4789765    HM402058 2004-12-30 20:00:00
# 4              3302   4677901    HM275615 2003-05-01 01:00:00
# 5              3633   4838048    HM440266 2004-08-01 00:01:00
# 6              3756   4791194    HM403711 2001-01-01 11:00:00
# 7              4502   4679521    HM216293 2003-03-15 00:00:00
# 8              4564   4792195    HM405396 2004-09-16 10:00:00
# 9              4904   4680124    HM282389 2003-01-01 00:00:00
# 10             6333   4682244    HM282286 2003-06-05 00:00:00
# 11             6564   4795453    HM409822 2004-11-01 00:01:00
# 12             7992   4684808    HM286351 2003-01-01 00:00:00
# 13             8901   4800321    HM414182 2004-11-01 00:00:00
# ...

# %%
df4['Date'].dt.time.value_counts()
# Out:
# 09:00:00    36006
# 12:00:00    35314
# 18:00:00    28290
# 15:00:00    26887
# 22:00:00    26717
# 17:00:00    26392
# 20:00:00    26191
# 19:00:00    26075
# 16:00:00    25268
# 21:00:00    24977
# 14:00:00    24592
# 10:00:00    24277
# 13:00:00    22274
# 08:00:00    22086
# 11:00:00    19278
# 23:00:00    18769
# 00:01:00    17582
# 00:00:00    16046
# 01:00:00    14452
# 15:30:00    13451
# 02:00:00    13231
# 18:30:00    12862
# 19:30:00    12758
# 22:30:00    12560
# 21:30:00    12510
# 16:30:00    12332
# 17:30:00    12332
# 07:00:00    12315
# 20:30:00    12297
# 14:30:00    12112
#             ...
# 19:43:55        1
# 10:06:30        1
# 11:01:58        1
# 17:13:21        1
# 19:11:14        1
# 19:27:43        1
# 04:32:12        1
# 15:58:31        1
# 17:44:55        1
# 08:42:31        1
# 16:34:05        1
# 17:10:11        1
# 16:55:14        1
# 12:37:47        1
# 10:48:40        1
# 17:23:44        1
# 11:19:24        1
# 19:50:45        1
# 19:12:10        1
# ...

# %%
def filterYearAndCountYear():
    for i in range(2001, 2017):
        df_new = dfTotal[(dfTotal['Date'].dt.year == i)]
        return(df_new['Date'].dt.time.value_counts())

# %%
filterYearAndCountYear(2002)
# Out:
# 12:00:00    10658
# 22:00:00     9203
# 16:30:00     3346
#             ...
# 05:19:34        1
# 19:10:27        1
# 21:51:11        1
# 10:21:03        1
# 22:06:26        1
# 11:13:20        1
# 16:51:18        1
# 10:18:08        1
# 18:24:43        1
# 02:59:09        1
# 19:38:50        1
# 21:14:45        1
# 13:14:22        1
# 08:03:59        1
# 16:27:14        1
# 10:44:10        1
# 13:48:06        1
# 17:04:40        1
# 12:18:53        1
# ...

# %%
def filterYearAndCount():
    for i in range(2001, 2017):
        df_new = dfTotal[(dfTotal['Date'].dt.year == i)]
        print("In " + str(i))
        print(df_new['Date'].dt.time.value_counts().head(1))

# %%
filterYearAndCount()
# Out:
# In 2001
# 12:00:00    12167
# Name: Date, dtype: int64
# In 2002
# 12:00:00    10658
# Name: Date, dtype: int64
# In 2003
# 12:00:00    10688
# Name: Date, dtype: int64
# In 2004
# 12:00:00    9230
# Name: Date, dtype: int64
# In 2005
# 12:00:00    10220
# Name: Date, dtype: int64
# In 2006
# 12:00:00    16953
# Name: Date, dtype: int64
# In 2007
# 00:00:00    13043
# Name: Date, dtype: int64
# In 2008
# 00:00:00    20464
# Name: Date, dtype: int64
# In 2009
# 12:00:00    17471
# Name: Date, dtype: int64
# In 2010
# 12:00:00    15626
# Name: Date, dtype: int64
# In 2011
# 09:00:00    8756
# Name: Date, dtype: int64
# In 2012
# 09:00:00    8516
# Name: Date, dtype: int64
# In 2013
# 09:00:00    7883
# Name: Date, dtype: int64
# In 2014
# 09:00:00    6926
# Name: Date, dtype: int64
# In 2015
# 12:00:00    6527
# Name: Date, dtype: int64
# In 2016
# 12:00:00    6576
# Name: Date, dtype: int64

# %%
filterYearAndCount(2004)
# Out:
# 12:00:00    9230
# 09:00:00    7424
# 22:00:00    7316
# 00:00:00    7289
# 20:00:00    6949
# 18:00:00    6890
# 21:00:00    6744
# 19:00:00    6616
# 15:00:00    6587
# 17:00:00    6185
# 16:00:00    6154
# 14:00:00    5761
# 23:00:00    5510
# 10:00:00    5337
# 13:00:00    5313
# 08:00:00    5169
# 11:00:00    4454
# 00:01:00    4240
# 01:00:00    3792
# 22:30:00    3431
# 15:30:00    3318
# 21:30:00    3310
# 02:00:00    3297
# 20:30:00    3277
# 14:30:00    3271
# 19:30:00    3175
# 18:30:00    3125
# 07:00:00    3078
# 23:30:00    3015
# 16:30:00    3001
#             ...
# 02:24:07       1
# 22:46:22       1
# 00:23:10       1
# 10:11:12       1
# 12:45:18       1
# 20:52:49       1
# 17:42:07       1
# 04:34:15       1
# 11:02:39       1
# 11:18:27       1
# 04:14:29       1
# 18:02:27       1
# 08:46:58       1
# 15:55:08       1
# 16:10:33       1
# 06:26:56       1
# 19:52:15       1
# 10:11:42       1
# 17:32:43       1
# 04:33:16       1
# 07:14:08       1
# ...
